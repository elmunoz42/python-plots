# %% [markdown]
# ### Codio Activity 4.3: Creating Scatterplots, Histograms, and Distribution Plots
#
# **Expected Time: 60 Minutes**
#
# **Total Points: 12**
#
# This activity focuses on using scatterplots to compare GDP and Life Expectancy.  The built in gapminder data offers GDP and Life Expectancy data similar to the videos, and you will use this to produce a scatterplot that contains more than two dimensions of data and an important transformation.
#
#
# ## Index:
#
# - [Problem 1](#Problem-1)
# - [Problem 2](#Problem-2)
# - [Problem 3](#Problem-3)
# - [Problem 4](#Problem-4)
# - [Problem 5](#Problem-5)
# - [Problem 6](#Problem-6)

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 1
#
# #### Scatter Plot of GDP vs. Life Expectancy
#
#
# Use `plotly` to create a scatter plot of the gapminder data with GDP on the $x$-axis and Life Expectancy on the $y$ axis.
#
# Use the `plt.savefig()` method to save the image as `img1.png` in the `images` folder.

# %%
### GRADED

px.scatter(gapminder, x='gdpPercap', y='lifeExp')
plt.savefig('images/img1.png')
plt.close()

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 2
#
# #### Scatter Plot of GDP vs. Life Expectancy with Country
#
# Use `plotly` to create a scatter plot of the gapminder data with GDP on the $x$-axis and Life Expectancy on the $y$ axis and add color to each point based on the `country` column.
#
# Use the `plt.savefig()` method to save the image as `img2.png` in the `images` folder.

# %%
### GRADED

px.scatter(gapminder, x='gdpPercap', y='lifeExp', color='country')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 3
#
# #### Incorporating Population
#
# Use `plotly` to create a scatter plot of the gapminder data with GDP on the $x$-axis and Life Expectancy on the $y$ axis, add color to each point based on the `country` column and size the points based on the population column.
#
# Use the `plt.savefig()` method to save the image as `img3.png` in the `images` folder.

# %%
### GRADED

px.scatter(gapminder, x='gdpPercap', y='lifeExp', color='country', size='pop')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 4
#
# #### Logarithmic Transformation
#
# Use `plotly` to create a scatter plot of the gapminder data with GDP on the $x$-axis and Life Expectancy on the $y$ axis, add color to each point based on the `country` column and size the points based on the population column.    Transform the $x$-axis using the `log_x` argument in the scatter function.
#
# Use the `plt.savefig()` method to save the image as `img3.png` in the `images` folder.

# %%
### GRADED

px.scatter(gapminder, x='gdpPercap', y='lifeExp', color='country', size='pop', log_x=True)

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 5
#
# #### Limit to the year 2007
#
# Limit the data to the year 2007 and create a scatterplot of GDP vs. Life Expectancy, color by country, size the points by population and use a logarithmic transform on the x-axis.
#
# Use the `plt.savefig()` method to save the image as `img5.png` in the `images` folder.

# %%
### GRADED

px.scatter(gapminder.query('year == 2007'), x='gdpPercap', y='lifeExp', color='country', size='pop', log_x=True)
# Out:
# <div>                            <div id="7db2a321-9420-4246-b81b-7ebbc2cd8f7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7db2a321-9420-4246-b81b-7ebbc2cd8f7c")) {                    Plotly.newPlot(                        "7db2a321-9420-4246-b81b-7ebbc2cd8f7c",                        [{"hovertemplate":"country=Afghanistan<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[31889923],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[974.5803384],"xaxis":"x","y":[43.828],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Albania<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","size":[3600523],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[5937.0295259999975],"xaxis":"x","y":[76.423],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Algeria<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","size":[33333216],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[6223.367465],"xaxis":"x","y":[72.301],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Angola<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Angola","marker":{"color":"#ab63fa","size":[12420476],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[4797.231267],"xaxis":"x","y":[42.731],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Argentina<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Argentina","marker":{"color":"#FFA15A","size":[40301927],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[12779.379640000001],"xaxis":"x","y":[75.32],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Australia<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Australia","marker":{"color":"#19d3f3","size":[20434176],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":[34435.367439999995],"xaxis":"x","y":[81.235],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Austria<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Austria","marker":{"color":"#FF6692","size":[8199783],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Austria","orientation":"v","showlegend":true,"x":[36126.4927],"xaxis":"x","y":[79.829],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Bahrain<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Bahrain","marker":{"color":"#B6E880","size":[708573],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Bahrain","orientation":"v","showlegend":true,"x":[29796.048339999998],"xaxis":"x","y":[75.635],"yaxis":"y","type":"scatter"},{"hovertemplate":"country=Bangladesh<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#FF97FF","size":[150448339],"sizemode":"area","sizeref":3296707.74,"symbol":"circle"},"mode":"markers","name":"Bangladesh","orientation":"v","showlegend":true,"x":[1391.253792],"xaxis":"x","y":[64.062],"yaxis":"y","type":"scatter"},{"hovertemplate":"count ...

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 6
#
# #### Boxplots for GDP by Continent
#
# Use `plotly` to create boxplots for GDP by continent.
#
# Use the `plt.savefig()` method to save the image as `img5.png` in the `images` folder.

# %%
### GRADED

px.box(gapminder, y='gdpPercap', color='continent')
# Out:
# <div>                            <div id="1ce93acd-04d0-444e-8307-0156fc03625e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ce93acd-04d0-444e-8307-0156fc03625e")) {                    Plotly.newPlot(                        "1ce93acd-04d0-444e-8307-0156fc03625e",                        [{"alignmentgroup":"True","hovertemplate":"continent=Asia<br>gdpPercap=%{y}<extra></extra>","legendgroup":"Asia","marker":{"color":"#636efa"},"name":"Asia","notched":false,"offsetgroup":"Asia","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":